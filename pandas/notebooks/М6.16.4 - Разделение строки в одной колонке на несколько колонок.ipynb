# %%
import pandas as pd

# %%
df = pd.DataFrame({'name':['John James Smith', 'Mary Ann Goldman'],
                   'location':['Los Angeles, CA', 'Washington, DC']})
df
# Out:
#                name         location
# 0  John James Smith  Los Angeles, CA
# 1  Mary Ann Goldman   Washington, DC

# %%
df.name.str.split(' ', expand=True)
# Out:
#       0      1        2
# 0  John  James    Smith
# 1  Mary    Ann  Goldman

# %%
df[['first', 'middle', 'last']] = df.name.str.split(' ', expand=True)
df
# Out:
#                name         location first middle     last
# 0  John James Smith  Los Angeles, CA  John  James    Smith
# 1  Mary Ann Goldman   Washington, DC  Mary    Ann  Goldman

# %%
df.location.str.split(', ', expand=True)
# Out:
#              0   1
# 0  Los Angeles  CA
# 1   Washington  DC

# %%
df['city'] = df.location.str.split(', ', expand=True)[0]
df
# Out:
#                name         location first middle     last         city
# 0  John James Smith  Los Angeles, CA  John  James    Smith  Los Angeles
# 1  Mary Ann Goldman   Washington, DC  Mary    Ann  Goldman   Washington
