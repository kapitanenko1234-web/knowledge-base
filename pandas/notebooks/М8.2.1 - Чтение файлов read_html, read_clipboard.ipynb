# %%
import pandas as pd
from IPython.display import Image

# %% [markdown]
# # Метод .read_html

# %% [markdown]
# Сайт ЦРБ, курс валют на сегодня https://cbr.ru/currency_base/daily/

# %%
display(Image(filename='files/скрин_html_elements.png'))

# %%
# парсим табличку с курсом валют с сайта ЦРБ
# .read_html() возвращает список таблиц, поэтому необходимо указать элемент списка, т.е. выбирать таблицу из списка
# воспользуемся ссылкой на сайт ЦРБ и укажем элемент '0'
df_currency = pd.read_html('https://cbr.ru/currency_base/daily/')[0]
df_currency
# Out:
#     Цифр. код Букв. код  Единиц                                    Валюта  \
# 0          36       AUD       1                      Австралийский доллар
# 1         944       AZN       1                     Азербайджанский манат
# 2          51       AMD     100                          Армянских драмов
# 3         933       BYN       1                         Белорусский рубль
# 4         975       BGN       1                            Болгарский лев
# 5         986       BRL       1                          Бразильский реал
# 6         348       HUF     100                       Венгерских форинтов
# 7         410       KRW    1000                      Вон Республики Корея
# 8         704       VND   10000                        Вьетнамских донгов
# 9         344       HKD       1                        Гонконгский доллар
# 10        981       GEL       1                           Грузинский лари
# 11        208       DKK       1                             Датская крона
# ...

# %% [markdown]
# # Метод .read_clipboard

# %%
# копируем в буфер обмена информацию с сайта https://cbr.ru/hd_base/infl/ 
# Ключевая ставка Банка России и инфляция c 13/01/23 по 12/07/23
df_inflation=pd.read_clipboard()
df_inflation
# Out:
#      Дата Ключевая ставка, % годовых Инфляция, % г/г Цель по инфляции, %
# 0  6.2023                       7,50            3,25                4,00
# 1  5.2023                       7,50            2,51                4,00
# 2  4.2023                       7,50            2,31                4,00
# 3  3.2023                       7,50            3,51                4,00
# 4  2.2023                       7,50           10,99                4,00
# 5  1.2023                       7,50           11,77                4,00

# %%
# записываем данные в файл csv
df_inflation.to_csv('files/inflation_Jan23_Jul23')

# %%
# скопируем кусок данных из файла xlsx
display(Image(filename='files/скрин_excel_наука.png'))

# %%
# кусок данных из буфера обмена переместился в датафрейм df_science
df_science=pd.read_clipboard()
df_science
# Out:
#             1 Математические и естественные науки
# 0  1.05.00.00                       Науки о Земле
# 1  1.05.02.01                         Картография
# 2  1.05.02.02                          Гидрология
# 3  1.05.02.03                        Метеорология

# %%
df_currency
# Out:
#     Цифр. код Букв. код  Единиц                                    Валюта  \
# 0          36       AUD       1                      Австралийский доллар
# 1         944       AZN       1                     Азербайджанский манат
# 2          51       AMD     100                          Армянских драмов
# 3         933       BYN       1                         Белорусский рубль
# 4         975       BGN       1                            Болгарский лев
# 5         986       BRL       1                          Бразильский реал
# 6         348       HUF     100                       Венгерских форинтов
# 7         410       KRW    1000                      Вон Республики Корея
# 8         704       VND   10000                        Вьетнамских донгов
# 9         344       HKD       1                        Гонконгский доллар
# 10        981       GEL       1                           Грузинский лари
# 11        208       DKK       1                             Датская крона
# ...

# %%
df_currency.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Цифр. код  43 non-null     int64
#  1   Букв. код  43 non-null     object
#  2   Единиц     43 non-null     int64
#  3   Валюта     43 non-null     object
#  4   Курс       43 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 1.8+ KB

# %%
# умножаем значения колонки 'Курс' на 0,0001
# получаем тип данных float
df_currency['Курс']=df_currency['Курс'].apply(lambda x: x*0.0001)
df_currency
# Out:
#     Цифр. код Букв. код  Единиц                                    Валюта  \
# 0          36       AUD       1                      Австралийский доллар
# 1         944       AZN       1                     Азербайджанский манат
# 2          51       AMD     100                          Армянских драмов
# 3         933       BYN       1                         Белорусский рубль
# 4         975       BGN       1                            Болгарский лев
# 5         986       BRL       1                          Бразильский реал
# 6         348       HUF     100                       Венгерских форинтов
# 7         410       KRW    1000                      Вон Республики Корея
# 8         704       VND   10000                        Вьетнамских донгов
# 9         344       HKD       1                        Гонконгский доллар
# 10        981       GEL       1                           Грузинский лари
# 11        208       DKK       1                             Датская крона
# ...

# %%
df['Ключевая ставка, % годовых'] = df['Ключевая ставка, % годовых'].apply(lambda x: x.replace(',', '.').strip())
df['Инфляция, % г/г'] = df['Инфляция, % г/г'].apply(lambda x: x.replace(',', '.').strip())
df['Цель по инфляции, %'] = df['Цель по инфляции, %'].apply(lambda x: x.replace(',', '.').strip())

# %%
df=pd.read_csv('files/inflation_Jan23_Jul23', index_col=[0])
df
# Out:
#      Дата Ключевая ставка, % годовых Инфляция, % г/г Цель по инфляции, %
# 0  6.2023                       7,50            3,25                4,00
# 1  5.2023                       7,50            2,51                4,00
# 2  4.2023                       7,50            2,31                4,00
# 3  3.2023                       7,50            3,51                4,00
# 4  2.2023                       7,50           10,99                4,00
# 5  1.2023                       7,50           11,77                4,00

# %%
df.info()

# %%
df=df.astype({'Дата':'object','Ключевая ставка, % годовых':'float64',
               'Инфляция, % г/г':'float64',
               'Цель по инфляции, %':'float64'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Дата                        6 non-null      object
#  1   Ключевая ставка, % годовых  6 non-null      float64
#  2   Инфляция, % г/г             6 non-null      float64
#  3   Цель по инфляции, %         6 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 240.0+ bytes

# %%
df['Дата']=pd.to_datetime(df['Дата'], format='%m.%Y')
df
# Out:
#         Дата  Ключевая ставка, % годовых  Инфляция, % г/г  Цель по инфляции, %
# 0 2023-06-01                         7.5             3.25                  4.0
# 1 2023-05-01                         7.5             2.51                  4.0
# 2 2023-04-01                         7.5             2.31                  4.0
# 3 2023-03-01                         7.5             3.51                  4.0
# 4 2023-02-01                         7.5            10.99                  4.0
# 5 2023-01-01                         7.5            11.77                  4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Дата                        6 non-null      datetime64[ns]
#  1   Ключевая ставка, % годовых  6 non-null      float64
#  2   Инфляция, % г/г             6 non-null      float64
#  3   Цель по инфляции, %         6 non-null      float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 240.0 bytes
